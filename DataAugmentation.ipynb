# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import librosa

# %%
# !pip install audiomentations
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\public\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\public\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\public\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\public\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\public\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\public\anaconda\lib\site-packages)

# %%
import librosa
import soundfile as sf
import audiomentations
from audiomentations import Compose, AddGaussianNoise, PitchShift, HighPassFilter

# %%
import librosa.display
import matplotlib.pyplot as plt

# %%
'''
- High pass filter
- Low pass filter
- Noise addition
- Time stretching (using librosa)
- Pitch scaling (using librosa)
- Polarity inversion
- Random gain
'''
# Out:
# '\n- High pass filter\n- Low pass filter\n- Noise addition\n- Time stretching (using librosa)\n- Pitch scaling (using librosa)\n- Polarity inversion\n- Random gain\n'

# %%
def _plot_signal_and_augmented_signal(signal, augmented_signal, sr):
    fig, ax = plt.subplots(nrows=2)
    librosa.display.waveshow(signal, sr=sr, ax=ax[0])
    ax[0].set(title="Original signal")
    librosa.display.waveshow(augmented_signal, sr=sr, ax=ax[1])
    ax[1].set(title="Augmented signal")
    plt.show()

# %%
gaussian_noise = AddGaussianNoise(
    min_amplitude=0.001,
    max_amplitude=0.015,
    p=1.0
)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_01.wav")
augmented_signal = gaussian_noise(signal, sr)
sf.write("Hindi1_01_GN.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_02.wav")
augmented_signal = gaussian_noise(signal, sr)
sf.write("Hindi1_02_GN.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_03.wav")
augmented_signal = gaussian_noise(signal, sr)
sf.write("Hindi1_03_GN.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_02.wav")
augmented_signal = gaussian_noise(signal, sr)
sf.write("HindiA_02_GN.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_01.wav")
augmented_signal = gaussian_noise(signal, sr)
sf.write("HindiA_01_GN.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_03.wav")
augmented_signal = gaussian_noise(signal, sr)
sf.write("HindiA_03_GN.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
pitch_shift = PitchShift(
    min_semitones=-5.0,
    max_semitones=5.0,
    p=1.0
)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_01.wav")
augmented_signal = pitch_shift(signal, sr)
sf.write("Hindi1_01_PS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_02.wav")
augmented_signal = pitch_shift(signal, sr)
sf.write("Hindi1_02_PS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_03.wav")
augmented_signal = pitch_shift(signal, sr)
sf.write("Hindi1_03_PS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_01.wav")
augmented_signal = pitch_shift(signal, sr)
sf.write("HindiA_01_PS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_02.wav")
augmented_signal = pitch_shift(signal, sr)
sf.write("HindiA_02_PS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_03.wav")
augmented_signal = pitch_shift(signal, sr)
sf.write("HindiA_03_PS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
from audiomentations import TimeStretch

time_stretch = TimeStretch(
    min_rate=0.8,
    max_rate=1.25,
    leave_length_unchanged=True,
    p=1.0
)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_01.wav")
augmented_signal = time_stretch(signal, sr)
sf.write("Hindi1_01_TS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_02.wav")
augmented_signal = time_stretch(signal, sr)
sf.write("Hindi1_02_TS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_03.wav")
augmented_signal = time_stretch(signal, sr)
sf.write("Hindi1_03_TS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_01.wav")
augmented_signal = time_stretch(signal, sr)
sf.write("HindiA_01_TS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_02.wav")
augmented_signal = time_stretch(signal, sr)
sf.write("HindiA_02_TS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_03.wav")
augmented_signal = time_stretch(signal, sr)
sf.write("HindiA_03_TS.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
high_pass_filter = HighPassFilter(min_cutoff_freq=2000, max_cutoff_freq=4000, p=1)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_01.wav")
augmented_signal = high_pass_filter(signal, sr)
sf.write("Hindi1_01_HPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_02.wav")
augmented_signal = high_pass_filter(signal, sr)
sf.write("Hindi1_02_HPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_03.wav")
augmented_signal = high_pass_filter(signal, sr)
sf.write("Hindi1_03_HPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_01.wav")
augmented_signal = high_pass_filter(signal, sr)
sf.write("HindiA_01_HPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_02.wav")
augmented_signal = high_pass_filter(signal, sr)
sf.write("HindiA_02_HPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_03.wav")
augmented_signal = high_pass_filter(signal, sr)
sf.write("HindiA_03_HPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
from audiomentations import TimeMask

time_mask = TimeMask(
    min_band_part=0.1,
    max_band_part=0.15,
    fade=True,
    p=1.0,
)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_01.wav")
augmented_signal = time_mask(signal, sr)
sf.write("Hindi1_01_TM.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_02.wav")
augmented_signal = time_mask(signal, sr)
sf.write("Hindi1_02_TM.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_03.wav")
augmented_signal = time_mask(signal, sr)
sf.write("Hindi1_03_TM.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_01.wav")
augmented_signal = time_mask(signal, sr)
sf.write("HindiA_01_TM.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_02.wav")
augmented_signal = time_mask(signal, sr)
sf.write("HindiA_02_TM.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_03.wav")
augmented_signal = time_mask(signal, sr)
sf.write("HindiA_03_TM.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
from audiomentations import Aliasing

aliasing = Aliasing(min_sample_rate=8000, max_sample_rate=30000, p=1.0)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_01.wav")
augmented_signal = aliasing(signal, sr)
sf.write("Hindi1_01_Alias.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_02.wav")
augmented_signal = aliasing(signal, sr)
sf.write("Hindi1_02_Alias.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_03.wav")
augmented_signal = aliasing(signal, sr)
sf.write("Hindi1_03_Alias.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_01.wav")
augmented_signal = aliasing(signal, sr)
sf.write("HindiA_01_Alias.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_02.wav")
augmented_signal = aliasing(signal, sr)
sf.write("HindiA_02_Alias.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_03.wav")
augmented_signal = aliasing(signal, sr)
sf.write("HindiA_03_Alias.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
from audiomentations import BandPassFilter

band_pass_filter = BandPassFilter(min_center_freq=100.0, max_center_freq=6000, p=1.0)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_01.wav")
augmented_signal = band_pass_filter(signal, sr)
sf.write("Hindi1_01_BPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_02.wav")
augmented_signal = band_pass_filter(signal, sr)
sf.write("Hindi1_02_BPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi dataset/Hindi1_03.wav")
augmented_signal = band_pass_filter(signal, sr)
sf.write("Hindi1_03_BPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_01.wav")
augmented_signal = band_pass_filter(signal, sr)
sf.write("HindiA_01_BPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_02.wav")
augmented_signal = band_pass_filter(signal, sr)
sf.write("HindiA_02_BPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)

# %%
signal, sr = librosa.load("Hindi A dataset/Hindi_03.wav")
augmented_signal = band_pass_filter(signal, sr)
sf.write("HindiA_03_BPF.wav", augmented_signal, sr)
_plot_signal_and_augmented_signal(signal, augmented_signal, sr)
